# %% [markdown]
# ### Data Loading and İmport the Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('plant_health_data.csv')
df.head()
# Out:
#                     Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  \
# 0  2024-10-03 10:54:53.407995         1      27.521109            22.240245
# 1  2024-10-03 16:54:53.407995         1      14.835566            21.706763
# 2  2024-10-03 22:54:53.407995         1      17.086362            21.180946
# 3  2024-10-04 04:54:53.407995         1      15.336156            22.593302
# 4  2024-10-04 10:54:53.407995         1      39.822216            28.929001
#
#    Soil_Temperature   Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  \
# 0         21.900435  55.291904       556.172805  5.581955       10.003650
# 1         18.680892  63.949181       596.136721  7.135705       30.712562
# 2         15.392939  67.837956       591.124627  5.656852       29.337002
# 3         22.778394  58.190811       241.412476  5.584523       16.966621
# 4         18.100937  63.772036       444.493830  5.919707       10.944961
#
#    Phosphorus_Level  Potassium_Level  Chlorophyll_Content  \
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               1200 non-null   object
#  1   Plant_ID                1200 non-null   int64
#  2   Soil_Moisture           1200 non-null   float64
#  3   Ambient_Temperature     1200 non-null   float64
#  4   Soil_Temperature        1200 non-null   float64
#  5   Humidity                1200 non-null   float64
#  6   Light_Intensity         1200 non-null   float64
#  7   Soil_pH                 1200 non-null   float64
#  8   Nitrogen_Level          1200 non-null   float64
#  9   Phosphorus_Level        1200 non-null   float64
#  10  Potassium_Level         1200 non-null   float64
#  11  Chlorophyll_Content     1200 non-null   float64
#  12  Electrochemical_Signal  1200 non-null   float64
#  13  Plant_Health_Status     1200 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Plant_ID                  0
# Soil_Moisture             0
# Ambient_Temperature       0
# Soil_Temperature          0
# Humidity                  0
# Light_Intensity           0
# Soil_pH                   0
# Nitrogen_Level            0
# Phosphorus_Level          0
# Potassium_Level           0
# Chlorophyll_Content       0
# Electrochemical_Signal    0
# Plant_Health_Status       0
# dtype: int64

# %%
df.describe()
# Out:
#           Plant_ID  Soil_Moisture  Ambient_Temperature  Soil_Temperature  \
# count  1200.000000    1200.000000          1200.000000       1200.000000
# mean      5.500000      25.106918            23.999130         19.957794
# std       2.873479       8.677725             3.441561          2.932073
# min       1.000000      10.000724            18.001993         15.003710
# 25%       3.000000      17.131893            21.101766         17.353027
# 50%       5.500000      25.168333            23.889044         19.911473
# 75%       8.000000      32.370231            27.042634         22.596851
# max      10.000000      39.993164            29.990886         24.995929
#
#           Humidity  Light_Intensity      Soil_pH  Nitrogen_Level  \
# count  1200.000000      1200.000000  1200.000000     1200.000000
# mean     54.853165       612.637265     6.524102       30.106751
# std       8.784916       228.318853     0.581755       11.514396
# ...

# %% [markdown]
# ### Data Analysis and Visualization

# %%
plt.figure(figsize=(9,6))
sns.countplot(data=df, x='Plant_Health_Status', palette='viridis' )
plt.title('Distrbution Plant Health')
plt.show()
# Out:
# /var/folders/d0/zdy0l5wj1md07992x9j7fdtm0000gn/T/ipykernel_4417/2407068169.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Plant_Health_Status', palette='viridis' )

# %%
plt.figure(figsize=(9,6))
sns.boxplot(data=df, x='Plant_Health_Status', y='Soil_Moisture', palette='viridis')
plt.title('Soil Moisture by Plant Health Status')
plt.show()
# Out:
# /var/folders/d0/zdy0l5wj1md07992x9j7fdtm0000gn/T/ipykernel_4417/539968266.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Plant_Health_Status', y='Soil_Moisture', palette='viridis')

# %%
plt.figure(figsize=(9,6))
sns.boxplot(data=df, x='Plant_Health_Status', y='Nitrogen_Level', palette='viridis')
plt.title('Soil Moisture by Plant Health Status')
plt.show()
# Out:
# /var/folders/d0/zdy0l5wj1md07992x9j7fdtm0000gn/T/ipykernel_4417/487073234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Plant_Health_Status', y='Nitrogen_Level', palette='viridis')

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Ambient_Temperature', y='Soil_Temperature', hue='Plant_Health_Status', data=df, palette='viridis')
plt.title('Ambient vs Soil Temperature colored by Plant Health')
plt.show()

# %%
# make all lines numeric and remove unnecessary lines
df.replace({'High Stress': 1, 'Moderate Stress':2 , 'Healthy': 3}, inplace=True)
df.drop(columns=['Timestamp', 'Plant_ID'], inplace=True)

# %% [markdown]
# ### Vi

# %%
# Correlation heatmap
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 10))
dfcorr =numeric_df.corr()
sns.heatmap(dfcorr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Splitting the dataset

# %%
X = df.drop(columns=['Plant_Health_Status'])
y=  df['Plant_Health_Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %% [markdown]
# ### Feature Scalling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Logistic Regression

# %%
lgmodel = LogisticRegression(max_iter=100)
lgmodel.fit(X_train,y_train)
lrpred = lgmodel.predict(X_test)

lga = classification_report(y_test, lrpred)
lcm = confusion_matrix(y_test, lrpred)

print(lga)
print(lcm)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.86      0.82        85
#            2       0.74      0.63      0.68        90
#            3       0.77      0.83      0.80        65
#
#     accuracy                           0.77       240
#    macro avg       0.77      0.77      0.77       240
# weighted avg       0.76      0.77      0.76       240
#
# [[73  9  3]
#  [20 57 13]
#  [ 0 11 54]]

# %%
plt.figure(figsize=(9,6))
sns.heatmap(lcm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=[' Predict High Stress', 'Predict Moderata Stress', 'Predict Healthy '],
            yticklabels=[])
plt.show()

# %%
from sklearn.svm import SVC
svmodel= SVC(kernel='linear', random_state=42, probability=True)
svmodel.fit(X_train, y_train)
svm_pred = svmodel.predict(X_test)

rep = classification_report(y_test, svm_pred)
cm = confusion_matrix(y_test, svm_pred)

print(rep)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.88      0.85        85
#            2       0.81      0.71      0.76        90
#            3       0.81      0.86      0.84        65
#
#     accuracy                           0.81       240
#    macro avg       0.81      0.82      0.81       240
# weighted avg       0.81      0.81      0.81       240
#
# [[75  6  4]
#  [17 64  9]
#  [ 0  9 56]]

# %%
dtmodel = DecisionTreeClassifier()

dtmodel.fit(X_train,y_train)

dtpred = dtmodel.predict(X_test)

dte = classification_report(y_test, dtpred)
cm = confusion_matrix(y_test, dtpred)

print(dte)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99        85
#            2       0.99      1.00      0.99        90
#            3       1.00      1.00      1.00        65
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
#
# [[84  1  0]
#  [ 0 90  0]
#  [ 0  0 65]]
